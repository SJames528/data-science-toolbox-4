# %%
import pandas as pd
data = pd.read_csv('../data/dataset.csv.gz', error_bad_lines=False);

# %%
print(len(data))
# Out:
# 16233

# %%
data
# Out:
#        28457823  javascript  \
# 0      28457823  javascript
# 1      28457823  javascript
# 2      28457823  javascript
# 3      28457823  javascript
# 4      28457823  javascript
# 5      28457823  javascript
# 6      28457823  javascript
# 7      28457823  javascript
# 8      28457823  javascript
# 9      28457823  javascript
# 10     28457823  javascript
# 11     28457823  javascript
# 12     28457823  javascript
# 13     28457823  javascript
# 14     28457823  javascript
# 15     28457823  javascript
# 16     28457823  javascript
# 17     28457823  javascript
# 18     28457823  javascript
# 19     28457823  javascript
# 20     28457823  javascript
# 21     28457823  javascript
# 22     28457823  javascript
# 23     28457823  javascript
# 24     28457823  javascript
# 25     28457823  javascript
# 26     28457823  javascript
# 27     28457823  javascript
# 28     28457823  javascript
# 29     28457823  javascript
# ...         ...         ...
# 16203  33015554           r
# ...

# %%
print(data[:4])
# Out:
#    28457823  javascript  \
# 0  28457823  javascript
# 1  28457823  javascript
# 2  28457823  javascript
# 3  28457823  javascript
#
#   b"module.exports = {\n  plugins: [\n    require.resolve('babel-plugin-transform-function-bind'),\n    require.resolve('@babel/plugin-proposal-class-properties'),\n    require.resolve('@babel/plugin-proposal-object-rest-spread'),\n  ],\n  presets: [\n    [\n      require.resolve('@babel/preset-env'),\n      {\n        targets: {\n          node: '10',\n        },\n      },\n    ],\n  ],\n};\n"
# 0  b"// The path where to mount the REST API app\...
# 1  b"import { Observable } from 'rx';\nimport deb...
# 2  b"import { Observable } from 'rx';\n// import ...
# 3  b"import { Observable } from 'rx';\n\nmodule.e...
